# %%
import numpy as np
import pandas as pd

# %%
pd.read_json("Data_CO2_Proyecto_1.json") # usamos el lector de json de pandas para volcarlo en un DF
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000      0.000000
# 1      Afghanistan                AFG  1751      0.000000      0.000000
# 2      Afghanistan                AFG  1752      0.000000      0.000000
# 3      Afghanistan                AFG  1753      0.000000      0.000000
# 4      Afghanistan                AFG  1754      0.000000      0.000000
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
df = pd.read_json("Data_CO2_Proyecto_1.json") # guardamos el df en una variable para poder jugar con ella

# %%
df # ahora el contenido del json ya lo vemos llamando a DF
# Out:
#            Country ISO 3166-1 alpha-3  Year         Total          Coal  \
# 0      Afghanistan                AFG  1750      0.000000      0.000000
# 1      Afghanistan                AFG  1751      0.000000      0.000000
# 2      Afghanistan                AFG  1752      0.000000      0.000000
# 3      Afghanistan                AFG  1753      0.000000      0.000000
# 4      Afghanistan                AFG  1754      0.000000      0.000000
# ...            ...                ...   ...           ...           ...
# 63099       Global                WLD  2017  36096.739276  14506.973805
# 63100       Global                WLD  2018  36826.506600  14746.830688
# 63101       Global                WLD  2019  37082.558969  14725.978025
# 63102       Global                WLD  2020  35264.085734  14174.564010
# 63103       Global                WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# ...

# %%
df.rename(columns = {'ISO 3166-1 alpha-3' : 'Country_Code', 'Per Capita' : 'Per_Capita'}, inplace=True)# renombramos la columna para que sea mas fcail trabajar con ella eliminando los espacios utliciamos INPLACE para q mdifique el DF

# %%
df
# Out:
#            Country Country_Code  Year         Total          Coal  \
# 0      Afghanistan          AFG  1750      0.000000      0.000000
# 1      Afghanistan          AFG  1751      0.000000      0.000000
# 2      Afghanistan          AFG  1752      0.000000      0.000000
# 3      Afghanistan          AFG  1753      0.000000      0.000000
# 4      Afghanistan          AFG  1754      0.000000      0.000000
# ...            ...          ...   ...           ...           ...
# 63099       Global          WLD  2017  36096.739276  14506.973805
# 63100       Global          WLD  2018  36826.506600  14746.830688
# 63101       Global          WLD  2019  37082.558969  14725.978025
# 63102       Global          WLD  2020  35264.085734  14174.564010
# 63103       Global          WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# 0          0.000000     0.000000     0.000000    0.000000    0.000000
# ...

# %% [markdown]
# # country_code y country son equivalentes?

# %%
# mediante el uso de unique, vamos a usar los valores unicos de una columna

# %%
df.Country.unique() # nos da los valores unicos
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bonaire, Saint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Canada', 'Cape Verde', 'Central African Republic',
#        'Chad', 'Chile', 'China', 'Christmas Island', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
#        'North Korea', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
len(df.Country.unique()) # contamos cuantos valores unicos hay
# Out:
# 232

# %%
df.Country_Code.unique() # hacemos lo mismo con country code
# Out:
# array(['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATA', 'ATG', 'ARG',
#        'ARM', 'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB',
#        'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BES', 'BIH', 'BWA',
#        'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CAN', 'CPV',
#        'CAF', 'TCD', 'CHL', 'CHN', 'CXR', 'COL', 'COM', 'COG', 'COK',
#        'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'PRK', 'COD',
#        'DNK', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI',
#        'EST', 'ETH', 'FRO', 'FSM', 'FJI', 'FIN', 'PCZ', 'FRA', 0, 'GUF',
#        'PYF', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GRL', 'GRD',
#        'GLP', 'GTM', 'GIN', 'GNB', 'GUY', 'HTI', 'HND', 'HKG', 'HUN',
#        'ISL', 'IND', 'IDN', 'IRQ', 'IRL', 'IRN', 'ISR', 'ITA', 'JAM',
#        'JPN', 'JOR', 'KAZ', 'KEN', 'KIR', 'KSV', 'KWT', 'KGZ', 'LAO',
#        'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX', 'MAC',
# ...

# %%
len(df.Country_Code.unique()) # vemos la longitud y comprobamos que no es la misma
# Out:
# 226

# %%
# tenemos 6 valores unicos menos en Country_code que en Country

# %%
df[df.Country_Code == 0]
# Out:
#                         Country Country_Code  Year  Total  Coal  Oil  Gas  \
# 19312  French Equatorial Africa            0  1750    0.0   0.0  0.0  0.0
# 19313  French Equatorial Africa            0  1751    0.0   0.0  0.0  0.0
# 19314  French Equatorial Africa            0  1752    0.0   0.0  0.0  0.0
# 19315  French Equatorial Africa            0  1753    0.0   0.0  0.0  0.0
# 19316  French Equatorial Africa            0  1754    0.0   0.0  0.0  0.0
# ...                         ...          ...   ...    ...   ...  ...  ...
# 47867            Ryukyu Islands            0  2017    0.0   0.0  0.0  0.0
# 47868            Ryukyu Islands            0  2018    0.0   0.0  0.0  0.0
# 47869            Ryukyu Islands            0  2019    0.0   0.0  0.0  0.0
# 47870            Ryukyu Islands            0  2020    0.0   0.0  0.0  0.0
# 47871            Ryukyu Islands            0  2021    0.0   0.0  0.0  0.0
#
#        Cement  Flaring  Other  Per_Capita
# ...

# %%
# tenemos 1632 filas donde Country_code es 0

# %%
df.Country[df.Country_Code == 0].unique() # asi sabemos cuantos paises unicos ultilizan el country code 0
# Out:
# array(['French Equatorial Africa', 'French West Africa',
#        'Kuwaiti Oil Fires', 'Leeward Islands', 'Pacific Islands (Palau)',
#        'Ryukyu Islands'], dtype=object)

# %%
# nos quedamos con Country pq hay 6 paisses que ultizan countrycode codificadas en 0

# %% [markdown]
# # EXPLORAMOS YEAR

# %%
df.Year.unique()
# Out:
# array([1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760,
#        1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771,
#        1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782,
#        1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793,
#        1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804,
#        1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815,
#        1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826,
#        1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837,
#        1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848,
#        1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859,
#        1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870,
#        1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881,
#        1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892,
# ...

# %%
len(df.Year.unique())
# Out:
# 272

# %%
# Out:
# 2021

# %%
min(df.Year.unique())
# Out:
# 1750

# %%
max(df.Year.unique()) - min(df.Year.unique()) # comprobamos que los años son consectivos
# Out:
# 271

# %%
# LOCALIZAR AÑO CONCRETO DENTRO DEL DATA SET

# %%
df[df.Year == 1980]
# Out:
#                        Country Country_Code  Year         Total         Coal  \
# 230                Afghanistan          AFG  1980      1.756302     0.315762
# 502                    Albania          ALB  1980      5.170837     2.322976
# 774                    Algeria          DZA  1980     66.416467     1.608496
# 1046                   Andorra          AND  1980      0.000000     0.000000
# 1318                    Angola          AGO  1980      5.334352     0.000000
# ...                        ...          ...   ...           ...          ...
# 61974                    Yemen          YEM  1980      3.313518     0.000000
# 62246                   Zambia          ZMB  1980      3.523262     1.352016
# 62518                 Zimbabwe          ZWE  1980      9.613952     7.712720
# 62790  International Transport          XIT  1980    446.415069     0.000000
# 63062                   Global          WLD  1980  19501.263339  7024.128811
#
# ...

# %%
# vamos a buscar un año y un pais en concreto

# %%
df[(df.Year == 1980) & (df.Country == 'Spain')]
# Out:
#       Country Country_Code  Year       Total       Coal         Oil       Gas  \
# 52454   Spain          ESP  1980  213.911907  49.251488  147.633552  3.986432
#
#           Cement  Flaring  Other  Per_Capita
# 52454  13.040435      0.0    0.0    5.705586

# %%
df[(df.Year == 1980) &~ (df.Country == 'Spain')]  # aqui pedimos lo que sea 1980 pero no sea España
# Out:
#                        Country Country_Code  Year         Total         Coal  \
# 230                Afghanistan          AFG  1980      1.756302     0.315762
# 502                    Albania          ALB  1980      5.170837     2.322976
# 774                    Algeria          DZA  1980     66.416467     1.608496
# 1046                   Andorra          AND  1980      0.000000     0.000000
# 1318                    Angola          AGO  1980      5.334352     0.000000
# ...                        ...          ...   ...           ...          ...
# 61974                    Yemen          YEM  1980      3.313518     0.000000
# 62246                   Zambia          ZMB  1980      3.523262     1.352016
# 62518                 Zimbabwe          ZWE  1980      9.613952     7.712720
# 62790  International Transport          XIT  1980    446.415069     0.000000
# 63062                   Global          WLD  1980  19501.263339  7024.128811
#
# ...

# %%
df[(df.Year == 1980) | (df.Year == 1977) & (df.Total > 300)]  ## año 1980 puede tener cualqui valor de total y el que sea 1977 si que tiene que ser mayor a 300
# Out:
#                        Country Country_Code  Year         Total         Coal  \
# 227                Afghanistan          AFG  1977      2.384175     0.450672
# 230                Afghanistan          AFG  1980      1.756302     0.315762
# 499                    Albania          ALB  1977      5.717343     1.699007
# 502                    Albania          ALB  1980      5.170837     2.322976
# 771                    Algeria          DZA  1977     41.844913     0.604560
# ...                        ...          ...   ...           ...          ...
# 62246                   Zambia          ZMB  1980      3.523262     1.352016
# 62515                 Zimbabwe          ZWE  1977      9.284411     7.357312
# 62518                 Zimbabwe          ZWE  1980      9.613952     7.712720
# 62790  International Transport          XIT  1980    446.415069     0.000000
# 63062                   Global          WLD  1980  19501.263339  7024.128811
#
# ...

# %%
df[((df.Year == 1980) | (df.Year == 1977)) & (df.Total > 300)] # aqui es un año u otro y que ademas sean mayores de 300
# Out:
#                        Country Country_Code  Year         Total         Coal  \
# 9475                    Canada          CAN  1977    407.790443    65.032336
# 9478                    Canada          CAN  1980    442.846874    81.171584
# 10835                    China          CHN  1977   1340.831115   998.608544
# 10838                    China          CHN  1980   1494.495884  1122.664256
# 19267                   France          FRA  1977    506.997659   122.908172
# 19270                   France          FRA  1980    511.112137   126.425924
# 21443                  Germany          DEU  1977   1052.608577   516.647780
# 21446                  Germany          DEU  1980   1100.065995   551.175520
# 27155                    Italy          ITA  1977    354.417634    31.367827
# 27158                    Italy          ITA  1980    386.433006    44.913312
# 27699                    Japan          JPN  1977    933.237686   204.520014
# ...

# %%
df[(df.Year == 1980) & (df.Country == 'Spain')]

# %% [markdown]
# # VAMOS A EXPLORAR TOTAL

# %%
# TENEMOS LA INTUCION DE QUE TOTAL ES LA SUMA DE TODO EL RESTO DE VALORES

# %%
df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']] # filtrado por columna q nos interesan
# Out:
#                Coal           Oil          Gas       Cement     Flaring  \
# 0          0.000000      0.000000     0.000000     0.000000    0.000000
# 1          0.000000      0.000000     0.000000     0.000000    0.000000
# 2          0.000000      0.000000     0.000000     0.000000    0.000000
# 3          0.000000      0.000000     0.000000     0.000000    0.000000
# 4          0.000000      0.000000     0.000000     0.000000    0.000000
# ...             ...           ...          ...          ...         ...
# 63099  14506.973805  12242.627935  7144.928128  1507.923185  391.992176
# 63100  14746.830688  12266.016285  7529.846784  1569.218392  412.115746
# 63101  14725.978025  12345.653374  7647.528220  1617.506786  439.253991
# 63102  14174.564010  11191.808551  7556.290283  1637.537532  407.583673
# 63103  14979.598083  11837.159116  7921.829472  1672.592372  416.525563
#
#             Other
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# ...

# %%
df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1)
# Out:
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
#              ...
# 63099    36096.739276
# 63100    36826.506601
# 63101    37082.558969
# 63102    35264.085734
# 63103    37123.850352
# Length: 63104, dtype: float64

# %%
df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1) - df.Total # restamos eso valores del total
# Out:
# 0        0.000000e+00
# 1        0.000000e+00
# 2        0.000000e+00
# 3        0.000000e+00
# 4        0.000000e+00
#              ...
# 63099    0.000000e+00
# 63100    1.000008e-06
# 63101   -7.275958e-12
# 63102    0.000000e+00
# 63103    0.000000e+00
# Length: 63104, dtype: float64

# %%
df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1) != df.Total
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 63099    False
# 63100     True
# 63101     True
# 63102    False
# 63103    False
# Length: 63104, dtype: bool

# %%
df[df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1) != df.Total] # en 9084 filas el total no coincide con la suma de las diferentes fuentes
# Out:
#            Country Country_Code  Year         Total          Coal  \
# 201    Afghanistan          AFG  1951      0.091600      0.025648
# 202    Afghanistan          AFG  1952      0.091600      0.031708
# 203    Afghanistan          AFG  1953      0.106256      0.037949
# 205    Afghanistan          AFG  1955      0.153888      0.062288
# 206    Afghanistan          AFG  1956      0.183200      0.062288
# ...            ...          ...   ...           ...           ...
# 63096       Global          WLD  2014  35577.534774  15051.512770
# 63097       Global          WLD  2015  35558.565735  14710.087469
# 63098       Global          WLD  2016  35524.193212  14360.605245
# 63100       Global          WLD  2018  36826.506600  14746.830688
# 63101       Global          WLD  2019  37082.558969  14725.978025
#
#                 Oil          Gas       Cement     Flaring       Other  \
# 201        0.065952     0.000000     0.000000    0.000000    0.000000
# ...

# %%
# vamos a ver cuales son las difrencias en esos registros, pq si son un quinto decimal igual no es significativa

# %%
df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1) - df.Total
# Out:
# 0        0.000000e+00
# 1        0.000000e+00
# 2        0.000000e+00
# 3        0.000000e+00
# 4        0.000000e+00
#              ...
# 63099    0.000000e+00
# 63100    1.000008e-06
# 63101   -7.275958e-12
# 63102    0.000000e+00
# 63103    0.000000e+00
# Length: 63104, dtype: float64

# %%
# primero definios que cantidad seria pequeña o grande para establecer condicion

# %%
df[df[['Coal', 'Oil', 'Gas', 'Cement', 'Flaring', 'Other']].sum(axis = 1) - df.Total >= 0.000001]
# Out:
#            Country Country_Code  Year         Total          Coal  \
# 230    Afghanistan          AFG  1980      1.756302      0.315762
# 472        Albania          ALB  1950      0.296725      0.043432
# 492        Albania          ALB  1970      3.739486      0.891225
# 499        Albania          ALB  1977      5.717343      1.699007
# 536        Albania          ALB  2014      5.999658      1.028913
# ...            ...          ...   ...           ...           ...
# 62970       Global          WLD  1888   1192.271841   1150.916587
# 62973       Global          WLD  1891   1358.873924   1309.094179
# 62982       Global          WLD  1900   1952.209498   1873.356867
# 63091       Global          WLD  2009  31564.030692  13016.427997
# 63100       Global          WLD  2018  36826.506600  14746.830688
#
#                 Oil          Gas       Cement     Flaring       Other  \
# 230        0.925256     0.187254     0.023284    0.304747    0.000000
# ...

# %%
# 0.000001 estas son las diferencias, son muy muy pequeñitas

# %% [markdown]
# ### PODEMOS DECIR CON SEGURIDAD QUE LA SUMA DE LAS DIFERENTES FUENTES DE CO2 SUMAN EL TOTAL

# %% [markdown]
# # VAMOS A EXPLORAR GLOBAL

# %%
# GLOBAL OCUPA EL ULTIMO LUGAR DE LA COLUMNA cOUNTRY

# %%
df[df.Country == 'Global']
# Out:
#       Country Country_Code  Year         Total          Coal           Oil  \
# 62832  Global          WLD  1750      9.350528      9.350528      0.000000
# 62833  Global          WLD  1751      9.350528      9.350528      0.000000
# 62834  Global          WLD  1752      9.354192      9.354192      0.000000
# 62835  Global          WLD  1753      9.354192      9.354192      0.000000
# 62836  Global          WLD  1754      9.357856      9.357856      0.000000
# ...       ...          ...   ...           ...           ...           ...
# 63099  Global          WLD  2017  36096.739276  14506.973805  12242.627935
# 63100  Global          WLD  2018  36826.506600  14746.830688  12266.016285
# 63101  Global          WLD  2019  37082.558969  14725.978025  12345.653374
# 63102  Global          WLD  2020  35264.085734  14174.564010  11191.808551
# 63103  Global          WLD  2021  37123.850352  14979.598083  11837.159116
#
#                Gas       Cement     Flaring       Other  Per_Capita
# ...

# %%
df.Total[df.Country != 'Global'].sum()
# Out:
# 1736930.029374

# %%
df.Total[df.Country == 'Global'].sum()
# Out:
# 1736930.0293219998

# %%
# vemos quue la diferencia es minima, lo que significa que GLOBAL, nos indica las emisiones globales por año, con esta info ya podemos marcar una linea de tendencia y asi ver la implicacion en cuanto a reducir el co2 los disitintos paises, compararlo con paises que hayan firmado tratados ectabs

# %%
# llama la atencion qque haya datos en totales para 1750, por lo cual ya hay algun pais con regiistro en esas fechas

# %%
df[df.Total != 0]
# Out:
#            Country Country_Code  Year         Total          Coal  \
# 199    Afghanistan          AFG  1949      0.014656      0.014656
# 200    Afghanistan          AFG  1950      0.084272      0.021068
# 201    Afghanistan          AFG  1951      0.091600      0.025648
# 202    Afghanistan          AFG  1952      0.091600      0.031708
# 203    Afghanistan          AFG  1953      0.106256      0.037949
# ...            ...          ...   ...           ...           ...
# 63099       Global          WLD  2017  36096.739276  14506.973805
# 63100       Global          WLD  2018  36826.506600  14746.830688
# 63101       Global          WLD  2019  37082.558969  14725.978025
# 63102       Global          WLD  2020  35264.085734  14174.564010
# 63103       Global          WLD  2021  37123.850352  14979.598083
#
#                 Oil          Gas       Cement     Flaring       Other  \
# 199        0.000000     0.000000     0.000000    0.000000    0.000000
# ...

# %%
# hay 21697 regstros con datos totales registrados, tenemos gran parte de nuestro data set a 0, de 63104 filas ya que solo 21697 que no tiene datos, por lo tanto el dataset no esta limpio

# %%
# como se median los datos en 19750?

# %%
# igual el dataset nos esta indicando con 0 valores que deberia ser nulos en años muy lejanos

# %%
# y en años actuales podriamos pensar que o bien no emitieron o bien no los pudieron registrar por algun motivo

# %%
### paises con registro de emisisones en 1750

# %%
df[(df.Total != 0) & (df.Year == 1750)] # comprobams qne en 1750 ya se media en UK, debido al carbon
# Out:
#               Country Country_Code  Year     Total      Coal  Oil  Gas  \
# 59296  United Kingdom          GBR  1750  9.350528  9.350528  0.0  0.0
# 62832          Global          WLD  1750  9.350528  9.350528  0.0  0.0
#
#        Cement  Flaring  Other  Per_Capita
# 59296     0.0      0.0    0.0    0.000000
# 62832     0.0      0.0    0.0    0.011492

# %%
# las nieblas londineneses mataban gente en esa epoca , por eso igual se empezo a medir el carbon, tendriamos que investigarlo

# %%
# la columna per capita puede no ser real, pq segun en que año no haba registros de poblacion

# %%
# vamos a localizar momentos en los que un pais empieza a obtener registrosabs

# %%
df[(df.Total != 0) & (df.Country == 'Spain')]
# Out:
#       Country Country_Code  Year       Total       Coal         Oil  \
# 52304   Spain          ESP  1830    0.003664   0.003664    0.000000
# 52305   Spain          ESP  1831    0.003664   0.003664    0.000000
# 52306   Spain          ESP  1832    0.003664   0.003664    0.000000
# 52307   Spain          ESP  1833    0.003664   0.003664    0.000000
# 52308   Spain          ESP  1834    0.003664   0.003664    0.000000
# ...       ...          ...   ...         ...        ...         ...
# 52491   Spain          ESP  2017  275.053205  53.592704  142.571508
# 52492   Spain          ESP  2018  270.052271  48.066131  143.531398
# 52493   Spain          ESP  2019  251.825149  23.622477  141.220887
# 52494   Spain          ESP  2020  213.339721  14.300041  120.283595
# 52495   Spain          ESP  2021  233.649543  18.575481  133.112623
#
#              Gas    Cement   Flaring     Other  Per_Capita
# 52304   0.000000  0.000000  0.000000  0.000000    0.000281
# ...
